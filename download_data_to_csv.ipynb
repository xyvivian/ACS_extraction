# %%
import censusdata
import pandas as pd

# %%
pd.set_option('display.expand_frame_repr',False)
pd.set_option('display.precision' ,2)

# %%
#Find the State of Florida's counties
censusdata.geographies(censusdata.censusgeo([('state', '12'), ('county', '*')]), 'acs5', 2018)
# Out:
# {'Okaloosa County, Florida': censusgeo((('state', '12'), ('county', '091'))),
#  'Taylor County, Florida': censusgeo((('state', '12'), ('county', '123'))),
#  'Washington County, Florida': censusgeo((('state', '12'), ('county', '133'))),
#  'Duval County, Florida': censusgeo((('state', '12'), ('county', '031'))),
#  'Bradford County, Florida': censusgeo((('state', '12'), ('county', '007'))),
#  'Brevard County, Florida': censusgeo((('state', '12'), ('county', '009'))),
#  'Clay County, Florida': censusgeo((('state', '12'), ('county', '019'))),
#  'Lafayette County, Florida': censusgeo((('state', '12'), ('county', '067'))),
#  'Lake County, Florida': censusgeo((('state', '12'), ('county', '069'))),
#  'Nassau County, Florida': censusgeo((('state', '12'), ('county', '089'))),
#  'Pinellas County, Florida': censusgeo((('state', '12'), ('county', '103'))),
#  'Polk County, Florida': censusgeo((('state', '12'), ('county', '105'))),
#  'St. Lucie County, Florida': censusgeo((('state', '12'), ('county', '111'))),
#  'Glades County, Florida': censusgeo((('state', '12'), ('county', '043'))),
#  'Hendry County, Florida': censusgeo((('state', '12'), ('county', '051'))),
#  'Indian River County, Florida': censusgeo((('state', '12'), ('county', '061'))),
#  'Jackson County, Florida': censusgeo((('state', '12'), ('county', '063'))),
#  'Palm Beach County, Florida': censusgeo((('state', '12'), ('county', '099'))),
#  'St. Johns County, Florida': censusgeo((('state', '12'), ('county', '109'))),
#  'Seminole County, Florida': censusgeo((('state', '12'), ('county', '117'))),
#  'Miami-Dade County, Florida': censusgeo((('state', '12'), ('county', '086'))),
#  'Bay County, Florida': censusgeo((('state', '12'), ('county', '005'))),
#  'Flagler County, Florida': censusgeo((('state', '12'), ('county', '035'))),
#  'Franklin County, Florida': censusgeo((('state', '12'), ('county', '037'))),
#  'Hamilton County, Florida': censusgeo((('state', '12'), ('county', '047'))),
#  'Liberty County, Florida': censusgeo((('state', '12'), ('county', '077'))),
#  'Sumter County, Florida': censusgeo((('state', '12'), ('county', '119'))),
#  'Gadsden County, Florida': censusgeo((('state', '12'), ('county', '039'))),
#  'Holmes County, Florida': censusgeo((('state', '12'), ('county', '059'))),
#  'Lee County, Florida': censusgeo((('state', '12'), ('county', '071'))),
#  'Marion County, Florida': censusgeo((('state', '12'), ('county', '083'))),
#  'Collier County, Florida': censusgeo((('state', '12'), ('county', '021'))),
#  'Orange County, Florida': censusgeo((('state', '12'), ('county', '095'))),
#  'Pasco County, Florida': censusgeo((('state', '12'), ('county', '101'))),
#  'Highlands County, Florida': censusgeo((('state', '12'), ('county', '055'))),
#  'Suwannee County, Florida': censusgeo((('state', '12'), ('county', '121'))),
#  'DeSoto County, Florida': censusgeo((('state', '12'), ('county', '027'))),
#  'Calhoun County, Florida': censusgeo((('state', '12'), ('county', '013'))),
#  'Columbia County, Florida': censusgeo((('state', '12'), ('county', '023'))),
#  'Dixie County, Florida': censusgeo((('state', '12'), ('county', '029'))),
#  'Putnam County, Florida': censusgeo((('state', '12'), ('county', '107'))),
#  'Union County, Florida': censusgeo((('state', '12'), ('county', '125'))),
#  'Manatee County, Florida': censusgeo((('state', '12'), ('county', '081'))),
#  'Levy County, Florida': censusgeo((('state', '12'), ('county', '075'))),
#  'Baker County, Florida': censusgeo((('state', '12'), ('county', '003'))),
#  'Volusia County, Florida': censusgeo((('state', '12'), ('county', '127'))),
#  'Leon County, Florida': censusgeo((('state', '12'), ('county', '073'))),
#  'Madison County, Florida': censusgeo((('state', '12'), ('county', '079'))),
#  'Escambia County, Florida': censusgeo((('state', '12'), ('county', '033'))),
#  'Hernando County, Florida': censusgeo((('state', '12'), ('county', '053'))),
#  'Wakulla County, Florida': censusgeo((('state', '12'), ('county', '129'))),
#  'Hillsborough County, Florida': censusgeo((('state', '12'), ('county', '057'))),
#  'Gulf County, Florida': censusgeo((('state', '12'), ('county', '045'))),
#  'Osceola County, Florida': censusgeo((('state', '12'), ('county', '097'))),
#  'Walton County, Florida': censusgeo((('state', '12'), ('county', '131'))),
#  'Jefferson County, Florida': censusgeo((('state', '12'), ('county', '065'))),
#  'Hardee County, Florida': censusgeo((('state', '12'), ('county', '049'))),
#  'Okeechobee County, Florida': censusgeo((('state', '12'), ('county', '093'))),
#  'Gilchrist County, Florida': censusgeo((('state', '12'), ('county', '041'))),
#  'Alachua County, Florida': censusgeo((('state', '12'), ('county', '001'))),
#  'Charlotte County, Florida': censusgeo((('state', '12'), ('county', '015'))),
#  'Martin County, Florida': censusgeo((('state', '12'), ('county', '085'))),
#  'Sarasota County, Florida': censusgeo((('state', '12'), ('county', '115'))),
#  'Citrus County, Florida': censusgeo((('state', '12'), ('county', '017'))),
#  'Santa Rosa County, Florida': censusgeo((('state', '12'), ('county', '113'))),
#  'Broward County, Florida': censusgeo((('state', '12'), ('county', '011'))),
#  'Monroe County, Florida': censusgeo((('state', '12'), ('county', '087')))}

# %%
#From the observations above, all county codes are:
county_list = ['091','123','133','031','007','009','019','067','069','089','103','105','111','043','051','061','063','099','109','117',
'086','005','035','037','047','077','119','039','059','071','083','021','095','101','055','121','027','013','023','029',
'107','125','081','075','003','127','073','079','033','053','129','057','045','097','131','065','049','093','041','001',
'015','085','115','017','113','011','087']

# %%
#download the census data for percentage of age
age_sex_data = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', '091'),
                                 ('block group', '*')]),['B01001_006E','B01001_007E',
                                                         'B01001_008E','B01001_009E',
                                                         'B01001_010E','B01001_011E',
                                                         'B01001_012E','B01001_013E',
                                                        'B01001_014E','B01001_015E',
                                                        'B01001_016E','B01001_017E',
                                                        'B01001_018E','B01001_019E',
                                                        'B01001_020E','B01001_021E',
                                                        'B01001_022E','B01001_023E',
                                                        'B01001_024E','B01001_025E',
                                                        'B01001_030E','B01001_031E',
                                                         'B01001_032E','B01001_033E',
                                                         'B01001_034E','B01001_035E',
                                                         'B01001_036E','B01001_037E',
                                                        'B01001_038E','B01001_039E',
                                                        'B01001_040E','B01001_041E',
                                                        'B01001_042E','B01001_043E',
                                                        'B01001_044E','B01001_045E',
                                                        'B01001_046E','B01001_047E',
                                                        'B01001_048E','B01001_049E'])

# %%
age_sex_data
# Out:
#                                                     B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  B01001_011E  B01001_012E  B01001_013E  B01001_014E  B01001_015E  ...  B01001_040E  B01001_041E  B01001_042E  B01001_043E  B01001_044E  B01001_045E  B01001_046E  B01001_047E  B01001_048E  B01001_049E
# Block Group 2, Census Tract 221, Okaloosa Count...           17           12            0           18           19           15           28           47           50           22  ...           36           70           17            5           26           50           11           48           30           24
# Block Group 1, Census Tract 221, Okaloosa Count...           57           11            0            0           19           73           59          151           23           48  ...           42           75           34           17            8           16           54           43           26            0
# Block Group 2, Census Tract 204, Okaloosa Count...           68           82           89           30           72          217          165          259           92           67  ...           28           61          121           12           11           34           16           14           30           23
# Block Group 1, Census Tract 204, Okaloosa Count...           31            0            0           50           15           45           97            0           17           40  ...           95           93            0           18            0           35           78           19            0            0
# Block Group 2, Census Tract 205, Okaloosa Count...            0            0            0            0           84           42           18           33            0           31  ...            0           14            0            0            0            0           13           30            0           12
# ...                                                         ...          ...          ...          ...          ...          ...          ...          ...          ...          ...  ...          ...          ...          ...          ...          ...          ...          ...          ...          ...          ...
# Block Group 2, Census Tract 217, Okaloosa Count...           24           13            1            2           24            7           40            0           33           21  ...           83            0            0            9           12           21           39            9           10           18
# Block Group 3, Census Tract 206, Okaloosa Count...          105          135           16           46          164          339          282          240          164          135  ...          182          170           61           29            0           23           74          107            0           25
# Block Group 1, Census Tract 225, Okaloosa Count...            0            0            0            0           18           22           35           27           21           12  ...           22           33           12           31           23            0           59           20           10            0
# Block Group 2, Census Tract 233.03, Okaloosa Co...            0            0            0            0            8            9            5           11           36           42  ...           18           46            8           29           29           32           41           10            5            8
# Block Group 5, Census Tract 233.03, Okaloosa Co...            0            0            0            0            0            0            0            0            0            5  ...            7            0           10            0            0            0           11            5            9            0
#
# [117 rows x 40 columns]

# %%
for i in county_list[1:]:
    age_sex_data_new = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', i),
                                 ('block group', '*')]),['B01001_006E','B01001_007E',
                                                         'B01001_008E','B01001_009E',
                                                         'B01001_010E','B01001_011E',
                                                         'B01001_012E','B01001_013E',
                                                        'B01001_014E','B01001_015E',
                                                        'B01001_016E','B01001_017E',
                                                        'B01001_018E','B01001_019E',
                                                        'B01001_020E','B01001_021E',
                                                        'B01001_022E','B01001_023E',
                                                        'B01001_024E','B01001_025E',
                                                        'B01001_030E','B01001_031E',
                                                         'B01001_032E','B01001_033E',
                                                         'B01001_034E','B01001_035E',
                                                         'B01001_036E','B01001_037E',
                                                        'B01001_038E','B01001_039E',
                                                        'B01001_040E','B01001_041E',
                                                        'B01001_042E','B01001_043E',
                                                        'B01001_044E','B01001_045E',
                                                        'B01001_046E','B01001_047E',
                                                        'B01001_048E','B01001_049E'])
    age_sex_data = age_sex_data.append(age_sex_data_new)

# %%
print(type(age_sex_data))
print(age_sex_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                     B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  B01001_011E  B01001_012E  B01001_013E  B01001_014E  B01001_015E  ...  B01001_040E  B01001_041E  B01001_042E  B01001_043E  B01001_044E  B01001_045E  B01001_046E  B01001_047E  B01001_048E  B01001_049E
# Block Group 2, Census Tract 221, Okaloosa Count...           17           12            0           18           19           15           28           47           50           22  ...           36           70           17            5           26           50           11           48           30           24
# Block Group 1, Census Tract 221, Okaloosa Count...           57           11            0            0           19           73           59          151           23           48  ...           42           75           34           17            8           16           54           43           26            0
# Block Group 2, Census Tract 204, Okaloosa Count...           68           82           89           30           72          217          165          259           92           67  ...           28           61          121           12           11           34           16           14           30           23
# Block Group 1, Census Tract 204, Okaloosa Count...           31            0            0           50           15           45           97            0           17           40  ...           95           93            0           18            0           35           78           19            0            0
# Block Group 2, Census Tract 205, Okaloosa Count...            0            0            0            0           84           42           18           33            0           31  ...            0           14            0            0            0            0           13           30            0           12
# ...                                                         ...          ...          ...          ...          ...          ...          ...          ...          ...          ...  ...          ...          ...          ...          ...          ...          ...          ...          ...          ...          ...
# Block Group 3, Census Tract 9705, Monroe County...            0           17            0            0            0           31           11           23           31           12  ...            0           83           15            0           42           14           11           11            0            0
# Block Group 2, Census Tract 9707, Monroe County...           15           22            0            0            0           21            5            0            8           29  ...           16            8            0            0            0            0            0           52            0            0
# Block Group 1, Census Tract 9708, Monroe County...            0            0            0            0           13            0           22           24           19           17  ...           53           46           22           75            0            0            9           15           17           21
# Block Group 3, Census Tract 9713, Monroe County...           12           33            0           22          109           11           58           41           19           45  ...           32           34            4           10            6            0           35            0            0            0
# Block Group 1, Census Tract 9710.02, Monroe Cou...            6            0            0            0            0           26            2            0            0           12  ...           14           17            0           30            0           18            0            0            3            0
#
# [11442 rows x 40 columns]

# %%
#here I divide the data into several categories
#20-30, 30-45, 45-60, 60+, because we do not need too much details about sex and age
age_sex_data['Age: 20-30'] = (age_sex_data.B01001_006E + age_sex_data.B01001_007E + age_sex_data.B01001_008E
                             +age_sex_data.B01001_009E + age_sex_data.B01001_010E  +age_sex_data.B01001_011E
                             + age_sex_data.B01001_030E + age_sex_data.B01001_031E + age_sex_data.B01001_032E
                             +age_sex_data.B01001_033E + age_sex_data.B01001_034E  +age_sex_data.B01001_035E)

age_sex_data['Age: 30-45'] = (age_sex_data.B01001_012E + age_sex_data.B01001_013E + age_sex_data.B01001_014E
                             +age_sex_data.B01001_036E + age_sex_data.B01001_037E  +age_sex_data.B01001_038E)

age_sex_data['Age: 45-60'] = (age_sex_data.B01001_015E + age_sex_data.B01001_016E + age_sex_data.B01001_017E
                             +age_sex_data.B01001_039E + age_sex_data.B01001_040E  +age_sex_data.B01001_041E)

age_sex_data['Age: 60+'] = (age_sex_data.B01001_018E + age_sex_data.B01001_019E + age_sex_data.B01001_020E
                             +age_sex_data.B01001_021E + age_sex_data.B01001_022E  +age_sex_data.B01001_023E
                           + age_sex_data.B01001_024E  +age_sex_data.B01001_025E
                             + age_sex_data.B01001_042E + age_sex_data.B01001_043E + age_sex_data.B01001_044E
                             +age_sex_data.B01001_045E + age_sex_data.B01001_046E  +age_sex_data.B01001_047E
                           + age_sex_data.B01001_048E  +age_sex_data.B01001_049E)

# %%
age_data = age_sex_data[['Age: 20-30','Age: 30-45','Age: 45-60',"Age: 60+"]]
age_data
# Out:
#                                                     Age: 20-30  Age: 30-45  Age: 45-60  Age: 60+
# Block Group 2, Census Tract 221, Okaloosa Count...         160         327         278       315
# Block Group 1, Census Tract 221, Okaloosa Count...         368         476         308       501
# Block Group 2, Census Tract 204, Okaloosa Count...         916         868         301       436
# Block Group 1, Census Tract 204, Okaloosa Count...         292         210         352       282
# Block Group 2, Census Tract 205, Okaloosa Count...         188          78          91       174
# ...                                                        ...         ...         ...       ...
# Block Group 3, Census Tract 9705, Monroe County...         103         114         169       268
# Block Group 2, Census Tract 9707, Monroe County...         139          34          91        59
# Block Group 1, Census Tract 9708, Monroe County...          48         187         292       408
# Block Group 3, Census Tract 9713, Monroe County...         268         150         168       225
# Block Group 1, Census Tract 9710.02, Monroe Cou...          51          34         167       131
#
# [11442 rows x 4 columns]

# %%
race_data = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', '091'),
                                 ('block group', '*')]),['B02001_002E','B02001_003E','B02001_004E','B02001_005E',
                                                         'B02001_006E'])

# %%
for i in county_list[1:]:
    race_data_new = censusdata.download('acs5', 2018,
            censusdata.censusgeo([('state', '12'),
                                 ('county', i),
                                 ('block group', '*')]),['B02001_002E','B02001_003E','B02001_004E','B02001_005E',
                                                         'B02001_006E'])
    race_data = race_data.append(race_data_new)

# %%
race_data
# Out:
#                                                     B02001_002E  B02001_003E  B02001_004E  B02001_005E  B02001_006E
# Block Group 2, Census Tract 221, Okaloosa Count...          946          200            0           36            0
# Block Group 1, Census Tract 221, Okaloosa Count...         1407          265            7           31          141
# Block Group 2, Census Tract 204, Okaloosa Count...         2662          343           13            0            0
# Block Group 1, Census Tract 204, Okaloosa Count...         1074          116            0           19            0
# Block Group 2, Census Tract 205, Okaloosa Count...          380          127            0           15           30
# ...                                                         ...          ...          ...          ...          ...
# Block Group 3, Census Tract 9705, Monroe County...          765            0            0            0            0
# Block Group 2, Census Tract 9707, Monroe County...          344            0            0            0            0
# Block Group 1, Census Tract 9708, Monroe County...          989            0            0            0            0
# Block Group 3, Census Tract 9713, Monroe County...          761           37            0           22            0
# Block Group 1, Census Tract 9710.02, Monroe Cou...          421           30            0            0            0
#
# [11442 rows x 5 columns]

# %%
race_data["Race: White"] = race_data.B02001_002E
race_data["Race: Black/African American"] = race_data.B02001_003E
race_data["Race: American Indian and Alaska Native"] = race_data.B02001_004E
race_data["Race: Asian"] = race_data.B02001_005E
race_data["Race: Hawaiian and Pacific Islander"] = race_data.B02001_006E
race_data= race_data[["Race: White","Race: Black/African American","Race: American Indian and Alaska Native",
                      "Race: Asian","Race: Hawaiian and Pacific Islander"]]

# %%
race_data
# Out:
#                                                     Race: White  Race: Black/African American  Race: American Indian and Alaska Native  Race: Asian  Race: Hawaiian and Pacific Islander
# Block Group 2, Census Tract 221, Okaloosa Count...          946                           200                                        0           36                                    0
# Block Group 1, Census Tract 221, Okaloosa Count...         1407                           265                                        7           31                                  141
# Block Group 2, Census Tract 204, Okaloosa Count...         2662                           343                                       13            0                                    0
# Block Group 1, Census Tract 204, Okaloosa Count...         1074                           116                                        0           19                                    0
# Block Group 2, Census Tract 205, Okaloosa Count...          380                           127                                        0           15                                   30
# ...                                                         ...                           ...                                      ...          ...                                  ...
# Block Group 3, Census Tract 9705, Monroe County...          765                             0                                        0            0                                    0
# Block Group 2, Census Tract 9707, Monroe County...          344                             0                                        0            0                                    0
# Block Group 1, Census Tract 9708, Monroe County...          989                             0                                        0            0                                    0
# Block Group 3, Census Tract 9713, Monroe County...          761                            37                                        0           22                                    0
# Block Group 1, Census Tract 9710.02, Monroe Cou...          421                            30                                        0            0                                    0
#
# [11442 rows x 5 columns]

# %%
education_data = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', '091'),
                                 ('block group', '*')]),['B29002_002E','B29002_003E','B29002_004E','B29002_005E',
                                                         'B29002_006E','B29002_007E','B29002_008E'])

# %%
for i in county_list[1:]:
    edu_data_new =  censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', i),
                                 ('block group', '*')]),['B29002_002E','B29002_003E','B29002_004E','B29002_005E',
                                                         'B29002_006E','B29002_007E','B29002_008E'])
    education_data = education_data.append(edu_data_new)

# %%
education_data["Education: Below Middle School"] = (education_data.B29002_002E)


education_data["Educatiohn: High School"] =  (education_data.B29002_003E + education_data.B29002_004E)


education_data["Education: College"] = (education_data.B29002_005E + education_data.B29002_006E + 
                                        education_data.B29002_007E)

education_data['Education: Graduate and Above'] = (education_data.B29002_008E) 

education_data= education_data[["Education: Below Middle School","Educatiohn: High School","Education: College", 'Education: Graduate and Above']]

# %%
education_data
# Out:
#                                                     Education: Below Middle School  Educatiohn: High School  Education: College  Education: Graduate and Above
# Block Group 2, Census Tract 221, Okaloosa Count...                              43                      626                 329                             26
# Block Group 1, Census Tract 221, Okaloosa Count...                              44                      709                 674                             96
# Block Group 2, Census Tract 204, Okaloosa Count...                             141                     1431                 744                              0
# Block Group 1, Census Tract 204, Okaloosa Count...                              18                      647                 311                             33
# Block Group 2, Census Tract 205, Okaloosa Count...                               0                      167                 277                             36
# ...                                                                            ...                      ...                 ...                            ...
# Block Group 3, Census Tract 9705, Monroe County...                              10                      168                 360                             69
# Block Group 2, Census Tract 9707, Monroe County...                               0                       49                 199                             50
# Block Group 1, Census Tract 9708, Monroe County...                              21                      234                 556                            110
# Block Group 3, Census Tract 9713, Monroe County...                              48                      257                 277                             12
# Block Group 1, Census Tract 9710.02, Monroe Cou...                               4                       76                 194                             52
#
# [11442 rows x 4 columns]

# %%
censusdata.printtable(censusdata.censustable('acs5', 2018, 'B29002'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B29002_001E  | CITIZEN, VOTING-AGE POPULATION | !! Estimate Total                                        | int
# B29002_002E  | CITIZEN, VOTING-AGE POPULATION | !! !! Estimate Total Less than 9th grade                 | int
# B29002_003E  | CITIZEN, VOTING-AGE POPULATION | !! !! Estimate Total 9th to 12th grade, no diploma       | int
# B29002_004E  | CITIZEN, VOTING-AGE POPULATION | !! !! Estimate Total High school graduate (includes equi | int
# B29002_005E  | CITIZEN, VOTING-AGE POPULATION | !! !! Estimate Total Some college, no degree             | int
# B29002_006E  | CITIZEN, VOTING-AGE POPULATION | !! !! Estimate Total Associate's degree                  | int
# B29002_007E  | CITIZEN, VOTING-AGE POPULATION | !! !! Estimate Total Bachelor's degree                   | int
# B29002_008E  | CITIZEN, VOTING-AGE POPULATION | !! !! Estimate Total Graduate or professional degree     | int
# -------------------------------------------------------------------------------------------------------------------

# %%
employment_data = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', '091'),
                                 ('block group', '*')]),['B23025_001E','B23025_002E','B23025_003E','B23025_004E',
                                                         'B23025_005E','B23025_006E','B23025_007E'])

# %%
for i in county_list[1:]:
    employment_data_new = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', i),
                                 ('block group', '*')]),['B23025_001E','B23025_002E','B23025_003E','B23025_004E',
                                                         'B23025_005E','B23025_006E','B23025_007E'])
    employment_data = employment_data.append(employment_data_new)

# %%
employment_data["Employment: Employed"] = employment_data.B23025_004E
employment_data["Employment: Unemployed"] = employment_data.B23025_005E
employment_data["Employment: Not In Labor Force"] = employment_data.B23025_007E
employment_data = employment_data[["Employment: Employed","Employment: Unemployed","Employment: Not In Labor Force"]]
employment_data
# Out:
#                                                     Employment: Employed  Employment: Unemployed  Employment: Not In Labor Force
# Block Group 2, Census Tract 221, Okaloosa Count...                   507                      26                             528
# Block Group 1, Census Tract 221, Okaloosa Count...                   799                      96                             683
# Block Group 2, Census Tract 204, Okaloosa Count...                   778                     275                            1392
# Block Group 1, Census Tract 204, Okaloosa Count...                   549                       0                             540
# Block Group 2, Census Tract 205, Okaloosa Count...                   304                      35                             192
# ...                                                                  ...                     ...                             ...
# Block Group 3, Census Tract 9705, Monroe County...                   402                       0                             252
# Block Group 2, Census Tract 9707, Monroe County...                   197                      10                             116
# Block Group 1, Census Tract 9708, Monroe County...                   503                       0                             432
# Block Group 3, Census Tract 9713, Monroe County...                   282                      15                             284
# Block Group 1, Census Tract 9710.02, Monroe Cou...                   269                       0                             106
#
# [11442 rows x 3 columns]

# %%
health_ins_data = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', '091'),
                                 ('block group', '*')]),['B27010_003E','B27010_010E','B27010_017E','B27010_019E',
                                                         'B27010_026E','B27010_033E','B27010_035E','B27010_042E',
                                                         'B27010_050E','B27010_052E','B27010_058E','B27010_066E'])

# %%
for i in county_list[1:]:
    health_data_new = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', i),
                                 ('block group', '*')]),['B27010_003E','B27010_010E','B27010_017E','B27010_019E',
                                                         'B27010_026E','B27010_033E','B27010_035E','B27010_042E',
                                                         'B27010_050E','B27010_052E','B27010_058E','B27010_066E'])
    health_ins_data = health_ins_data.append(health_data_new)
health_ins_data
# Out:
#                                                     B27010_003E  B27010_010E  B27010_017E  B27010_019E  B27010_026E  B27010_033E  B27010_035E  B27010_042E  B27010_050E  B27010_052E  B27010_058E  B27010_066E
# Block Group 2, Census Tract 221, Okaloosa Count...          242           15           21          128            0           85          246          189           91           71          210            0
# Block Group 1, Census Tract 221, Okaloosa Count...          378           25          110          179           15          188          521          176          178           23          226           11
# Block Group 2, Census Tract 204, Okaloosa Count...          837          215           16          360           57          119          656           42           90           79          124           11
# Block Group 1, Census Tract 204, Okaloosa Count...          156           16          124           70           55          200          189          139          132           65          159            0
# Block Group 2, Census Tract 205, Okaloosa Count...           85           18            0           75           46           67          140           11            0           17          157            0
# ...                                                         ...          ...          ...          ...          ...          ...          ...          ...          ...          ...          ...          ...
# Block Group 3, Census Tract 9705, Monroe County...          109           24            9           59            0           47          185            0          122           94          139            0
# Block Group 2, Census Tract 9707, Monroe County...           49           17           10           81            0           21          104           10            0           52            7            0
# Block Group 1, Census Tract 9708, Monroe County...          104            0           12           35           26           13          530           26           32           95          164            0
# Block Group 3, Census Tract 9713, Monroe County...           31            0           12            4            0           84          103           30          180           42          113           13
# Block Group 1, Census Tract 9710.02, Monroe Cou...           73            6            6           20            0           16          180           66           25            9           42            0
#
# [11442 rows x 12 columns]

# %%
health_ins_data["Insurance: 2 or More"] = health_ins_data.B27010_010E + health_ins_data.B27010_026E + health_ins_data.B27010_042E +health_ins_data.B27010_058E
health_ins_data["Insurance: One"] = health_ins_data.B27010_003E + health_ins_data.B27010_019E  +health_ins_data.B27010_035E +health_ins_data.B27010_052E
health_ins_data["Insurance: No"] = health_ins_data.B27010_017E + health_ins_data.B27010_033E   + health_ins_data.B27010_050E + health_ins_data.B27010_066E
health_ins_data = health_ins_data[["Insurance: 2 or More", "Insurance: One", "Insurance: No"]]
health_ins_data
# Out:
#                                                     Insurance: 2 or More  Insurance: One  Insurance: No
# Block Group 2, Census Tract 221, Okaloosa Count...                   414             687            197
# Block Group 1, Census Tract 221, Okaloosa Count...                   442            1101            487
# Block Group 2, Census Tract 204, Okaloosa Count...                   438            1932            236
# Block Group 1, Census Tract 204, Okaloosa Count...                   369             480            456
# Block Group 2, Census Tract 205, Okaloosa Count...                   232             317             67
# ...                                                                  ...             ...            ...
# Block Group 3, Census Tract 9705, Monroe County...                   163             447            178
# Block Group 2, Census Tract 9707, Monroe County...                    34             286             31
# Block Group 1, Census Tract 9708, Monroe County...                   216             764             57
# Block Group 3, Census Tract 9713, Monroe County...                   143             180            289
# Block Group 1, Census Tract 9710.02, Monroe Cou...                   114             282             47
#
# [11442 rows x 3 columns]

# %%
censusdata.search('acs5', 2018, 'label', 'health insurance')
# Out:
# [('B18135_004E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!Under 19 years!!With a disability!!With health insurance coverage'),
#  ('B18135_005E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!Under 19 years!!With a disability!!With health insurance coverage!!With private health insurance coverage'),
#  ('B18135_006E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!Under 19 years!!With a disability!!With health insurance coverage!!With public health coverage'),
#  ('B18135_007E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!Under 19 years!!With a disability!!No health insurance coverage'),
#  ('B18135_009E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!Under 19 years!!No disability!!With health insurance coverage'),
#  ('B18135_010E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!Under 19 years!!No disability!!With health insurance coverage!!With private health insurance coverage'),
#  ('B18135_011E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!Under 19 years!!No disability!!With health insurance coverage!!With public health coverage'),
#  ('B18135_012E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!Under 19 years!!No disability!!No health insurance coverage'),
#  ('B18135_015E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!19 to 64 years!!With a disability!!With health insurance coverage'),
#  ('B18135_016E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!19 to 64 years!!With a disability!!With health insurance coverage!!With private health insurance coverage'),
#  ('B18135_017E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!19 to 64 years!!With a disability!!With health insurance coverage!!With public health coverage'),
#  ('B18135_018E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!19 to 64 years!!With a disability!!No health insurance coverage'),
#  ('B18135_020E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!19 to 64 years!!No disability!!With health insurance coverage'),
#  ('B18135_021E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!19 to 64 years!!No disability!!With health insurance coverage!!With private health insurance coverage'),
#  ('B18135_022E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!19 to 64 years!!No disability!!With health insurance coverage!!With public health coverage'),
#  ('B18135_023E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!19 to 64 years!!No disability!!No health insurance coverage'),
#  ('B18135_026E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!65 years and over!!With a disability!!With health insurance coverage'),
#  ('B18135_027E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!65 years and over!!With a disability!!With health insurance coverage!!With private health insurance coverage'),
#  ('B18135_028E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!65 years and over!!With a disability!!With health insurance coverage!!With public health coverage'),
#  ('B18135_029E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!65 years and over!!With a disability!!No health insurance coverage'),
#  ('B18135_031E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!65 years and over!!No disability!!With health insurance coverage'),
#  ('B18135_032E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!65 years and over!!No disability!!With health insurance coverage!!With private health insurance coverage'),
#  ('B18135_033E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!65 years and over!!No disability!!With health insurance coverage!!With public health coverage'),
#  ('B18135_034E',
#   'AGE BY DISABILITY STATUS BY HEALTH INSURANCE COVERAGE STATUS',
#   'Estimate!!Total!!65 years and over!!No disability!!No health insurance coverage'),
#  ('B27001_004E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!Under 6 years!!With health insurance coverage'),
#  ('B27001_005E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!Under 6 years!!No health insurance coverage'),
#  ('B27001_007E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!6 to 18 years!!With health insurance coverage'),
#  ('B27001_008E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!6 to 18 years!!No health insurance coverage'),
#  ('B27001_010E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!19 to 25 years!!With health insurance coverage'),
#  ('B27001_011E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!19 to 25 years!!No health insurance coverage'),
#  ('B27001_013E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!26 to 34 years!!With health insurance coverage'),
#  ('B27001_014E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!26 to 34 years!!No health insurance coverage'),
#  ('B27001_016E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!35 to 44 years!!With health insurance coverage'),
#  ('B27001_017E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!35 to 44 years!!No health insurance coverage'),
#  ('B27001_019E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!45 to 54 years!!With health insurance coverage'),
#  ('B27001_020E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!45 to 54 years!!No health insurance coverage'),
#  ('B27001_022E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!55 to 64 years!!With health insurance coverage'),
#  ('B27001_023E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!55 to 64 years!!No health insurance coverage'),
#  ('B27001_025E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!65 to 74 years!!With health insurance coverage'),
#  ('B27001_026E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!65 to 74 years!!No health insurance coverage'),
#  ('B27001_028E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!75 years and over!!With health insurance coverage'),
#  ('B27001_029E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!75 years and over!!No health insurance coverage'),
#  ('B27001_032E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!Under 6 years!!With health insurance coverage'),
#  ('B27001_033E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!Under 6 years!!No health insurance coverage'),
#  ('B27001_035E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!6 to 18 years!!With health insurance coverage'),
#  ('B27001_036E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!6 to 18 years!!No health insurance coverage'),
#  ('B27001_038E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!19 to 25 years!!With health insurance coverage'),
#  ('B27001_039E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!19 to 25 years!!No health insurance coverage'),
#  ('B27001_041E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!26 to 34 years!!With health insurance coverage'),
#  ('B27001_042E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!26 to 34 years!!No health insurance coverage'),
#  ('B27001_044E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!35 to 44 years!!With health insurance coverage'),
#  ('B27001_045E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!35 to 44 years!!No health insurance coverage'),
#  ('B27001_047E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!45 to 54 years!!With health insurance coverage'),
#  ('B27001_048E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!45 to 54 years!!No health insurance coverage'),
#  ('B27001_050E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!55 to 64 years!!With health insurance coverage'),
#  ('B27001_051E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!55 to 64 years!!No health insurance coverage'),
#  ('B27001_053E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!65 to 74 years!!With health insurance coverage'),
#  ('B27001_054E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!65 to 74 years!!No health insurance coverage'),
#  ('B27001_056E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!75 years and over!!With health insurance coverage'),
#  ('B27001_057E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!75 years and over!!No health insurance coverage'),
#  ('B27002_004E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!Under 6 years!!With private health insurance'),
#  ('B27002_005E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!Under 6 years!!No private health insurance'),
#  ('B27002_007E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!6 to 18 years!!With private health insurance'),
#  ('B27002_008E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!6 to 18 years!!No private health insurance'),
#  ('B27002_010E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!19 to 25 years!!With private health insurance'),
#  ('B27002_011E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!19 to 25 years!!No private health insurance'),
#  ('B27002_013E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!26 to 34 years!!With private health insurance'),
#  ('B27002_014E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!26 to 34 years!!No private health insurance'),
#  ('B27002_016E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!35 to 44 years!!With private health insurance'),
#  ('B27002_017E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!35 to 44 years!!No private health insurance'),
#  ('B27002_019E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!45 to 54 years!!With private health insurance'),
#  ('B27002_020E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!45 to 54 years!!No private health insurance'),
#  ('B27002_022E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!55 to 64 years!!With private health insurance'),
#  ('B27002_023E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!55 to 64 years!!No private health insurance'),
#  ('B27002_025E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!65 to 74 years!!With private health insurance'),
#  ('B27002_026E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!65 to 74 years!!No private health insurance'),
#  ('B27002_028E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!75 years and over!!With private health insurance'),
#  ('B27002_029E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Male!!75 years and over!!No private health insurance'),
#  ('B27002_032E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!Under 6 years!!With private health insurance'),
#  ('B27002_033E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!Under 6 years!!No private health insurance'),
#  ('B27002_035E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!6 to 18 years!!With private health insurance'),
#  ('B27002_036E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!6 to 18 years!!No private health insurance'),
#  ('B27002_038E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!19 to 25 years!!With private health insurance'),
#  ('B27002_039E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!19 to 25 years!!No private health insurance'),
#  ('B27002_041E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!26 to 34 years!!With private health insurance'),
#  ('B27002_042E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!26 to 34 years!!No private health insurance'),
#  ('B27002_044E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!35 to 44 years!!With private health insurance'),
#  ('B27002_045E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!35 to 44 years!!No private health insurance'),
#  ('B27002_047E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!45 to 54 years!!With private health insurance'),
#  ('B27002_048E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!45 to 54 years!!No private health insurance'),
#  ('B27002_050E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!55 to 64 years!!With private health insurance'),
#  ('B27002_051E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!55 to 64 years!!No private health insurance'),
#  ('B27002_053E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!65 to 74 years!!With private health insurance'),
#  ('B27002_054E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!65 to 74 years!!No private health insurance'),
#  ('B27002_056E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!75 years and over!!With private health insurance'),
#  ('B27002_057E',
#   'PRIVATE HEALTH INSURANCE STATUS BY SEX BY AGE',
#   'Estimate!!Total!!Female!!75 years and over!!No private health insurance'),
#  ('B27010_003E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With one type of health insurance coverage'),
#  ('B27010_004E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With one type of health insurance coverage!!With employer-based health insurance only'),
#  ('B27010_005E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With one type of health insurance coverage!!With direct-purchase health insurance only'),
#  ('B27010_006E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With one type of health insurance coverage!!With Medicare coverage only'),
#  ('B27010_007E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With one type of health insurance coverage!!With Medicaid/means-tested public coverage only'),
#  ('B27010_008E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With one type of health insurance coverage!!With TRICARE/military health coverage only'),
#  ('B27010_009E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With one type of health insurance coverage!!With VA Health Care only'),
#  ('B27010_010E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With two or more types of health insurance coverage'),
#  ('B27010_011E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With two or more types of health insurance coverage!!With employer-based and direct-purchase coverage'),
#  ('B27010_012E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With two or more types of health insurance coverage!!With employer-based and Medicare coverage'),
#  ('B27010_013E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With two or more types of health insurance coverage!!With Medicare and Medicaid/means-tested public coverage'),
#  ('B27010_014E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With two or more types of health insurance coverage!!Other private only combinations'),
#  ('B27010_015E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With two or more types of health insurance coverage!!Other public only combinations'),
#  ('B27010_016E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!With two or more types of health insurance coverage!!Other coverage combinations'),
#  ('B27010_017E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!Under 19 years!!No health insurance coverage'),
#  ('B27010_019E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With one type of health insurance coverage'),
#  ('B27010_020E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With one type of health insurance coverage!!With employer-based health insurance only'),
#  ('B27010_021E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With one type of health insurance coverage!!With direct-purchase health insurance only'),
#  ('B27010_022E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With one type of health insurance coverage!!With Medicare coverage only'),
#  ('B27010_023E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With one type of health insurance coverage!!With Medicaid/means-tested public coverage only'),
#  ('B27010_024E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With one type of health insurance coverage!!With TRICARE/military health coverage only'),
#  ('B27010_025E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With one type of health insurance coverage!!With VA Health Care only'),
#  ('B27010_026E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With two or more types of health insurance coverage'),
#  ('B27010_027E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With two or more types of health insurance coverage!!With employer-based and direct-purchase coverage'),
#  ('B27010_028E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With two or more types of health insurance coverage!!With employer-based and Medicare coverage'),
#  ('B27010_029E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With two or more types of health insurance coverage!!With Medicare and Medicaid/means-tested public coverage'),
#  ('B27010_030E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With two or more types of health insurance coverage!!Other private only combinations'),
#  ('B27010_031E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With two or more types of health insurance coverage!!Other public only combinations'),
#  ('B27010_032E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!With two or more types of health insurance coverage!!Other coverage combinations'),
#  ('B27010_033E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!19 to 34 years!!No health insurance coverage'),
#  ('B27010_035E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With one type of health insurance coverage'),
#  ('B27010_036E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With one type of health insurance coverage!!With employer-based health insurance only'),
#  ('B27010_037E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With one type of health insurance coverage!!With direct-purchase health insurance only'),
#  ('B27010_038E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With one type of health insurance coverage!!With Medicare coverage only'),
#  ('B27010_039E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With one type of health insurance coverage!!With Medicaid/means-tested public coverage only'),
#  ('B27010_040E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With one type of health insurance coverage!!With TRICARE/military health coverage only'),
#  ('B27010_041E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With one type of health insurance coverage!!With VA Health Care only'),
#  ('B27010_042E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With two or more types of health insurance coverage'),
#  ('B27010_043E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With two or more types of health insurance coverage!!With employer-based and direct-purchase coverage'),
#  ('B27010_044E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With two or more types of health insurance coverage!!With employer-based and Medicare coverage'),
#  ('B27010_045E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With two or more types of health insurance coverage!!With direct-purchase and Medicare coverage'),
#  ('B27010_046E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With two or more types of health insurance coverage!!With Medicare and Medicaid/means-tested public coverage'),
#  ('B27010_047E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With two or more types of health insurance coverage!!Other private only combinations'),
#  ('B27010_048E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With two or more types of health insurance coverage!!Other public only combinations'),
#  ('B27010_049E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!With two or more types of health insurance coverage!!Other coverage combinations'),
#  ('B27010_050E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!35 to 64 years!!No health insurance coverage'),
#  ('B27010_052E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With one type of health insurance coverage'),
#  ('B27010_053E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With one type of health insurance coverage!!With employer-based health insurance only'),
#  ('B27010_054E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With one type of health insurance coverage!!With direct-purchase health insurance only'),
#  ('B27010_055E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With one type of health insurance coverage!!With Medicare coverage only'),
#  ('B27010_056E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With one type of health insurance coverage!!With TRICARE/military health coverage only'),
#  ('B27010_057E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With one type of health insurance coverage!!With VA Health Care only'),
#  ('B27010_058E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With two or more types of health insurance coverage'),
#  ('B27010_059E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With two or more types of health insurance coverage!!With employer-based and direct-purchase coverage'),
#  ('B27010_060E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With two or more types of health insurance coverage!!With employer-based and Medicare coverage'),
#  ('B27010_061E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With two or more types of health insurance coverage!!With direct-purchase and Medicare coverage'),
#  ('B27010_062E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With two or more types of health insurance coverage!!With Medicare and Medicaid/means-tested public coverage'),
#  ('B27010_063E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With two or more types of health insurance coverage!!Other private only combinations'),
#  ('B27010_064E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With two or more types of health insurance coverage!!Other public only combinations'),
#  ('B27010_065E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!With two or more types of health insurance coverage!!Other coverage combinations'),
#  ('B27010_066E',
#   'TYPES OF HEALTH INSURANCE COVERAGE BY AGE',
#   'Estimate!!Total!!65 years and over!!No health insurance coverage'),
#  ('B27011_004E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!In labor force!!Employed!!With health insurance coverage'),
#  ('B27011_005E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!In labor force!!Employed!!With health insurance coverage!!With private health insurance'),
#  ('B27011_006E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!In labor force!!Employed!!With health insurance coverage!!With public coverage'),
#  ('B27011_007E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!In labor force!!Employed!!No health insurance coverage'),
#  ('B27011_009E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!In labor force!!Unemployed!!With health insurance coverage'),
#  ('B27011_010E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!In labor force!!Unemployed!!With health insurance coverage!!With private health insurance'),
#  ('B27011_011E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!In labor force!!Unemployed!!With health insurance coverage!!With public coverage'),
#  ('B27011_012E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!In labor force!!Unemployed!!No health insurance coverage'),
#  ('B27011_014E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!Not in labor force!!With health insurance coverage'),
#  ('B27011_015E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!Not in labor force!!With health insurance coverage!!With private health insurance'),
#  ('B27011_016E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!Not in labor force!!With health insurance coverage!!With public coverage'),
#  ('B27011_017E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY EMPLOYMENT STATUS',
#   'Estimate!!Total!!Not in labor force!!No health insurance coverage'),
#  ('B27015_003E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!Under $25,000!!With health insurance coverage'),
#  ('B27015_004E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!Under $25,000!!With health insurance coverage!!With private health insurance'),
#  ('B27015_005E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!Under $25,000!!With health insurance coverage!!With public coverage'),
#  ('B27015_006E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!Under $25,000!!No health insurance coverage'),
#  ('B27015_008E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$25,000 to $49,999!!With health insurance coverage'),
#  ('B27015_009E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$25,000 to $49,999!!With health insurance coverage!!With private health insurance'),
#  ('B27015_010E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$25,000 to $49,999!!With health insurance coverage!!With public coverage'),
#  ('B27015_011E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$25,000 to $49,999!!No health insurance coverage'),
#  ('B27015_013E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$50,000 to $74,999!!With health insurance coverage'),
#  ('B27015_014E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$50,000 to $74,999!!With health insurance coverage!!With private health insurance'),
#  ('B27015_015E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$50,000 to $74,999!!With health insurance coverage!!With public coverage'),
#  ('B27015_016E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$50,000 to $74,999!!No health insurance coverage'),
#  ('B27015_018E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$75,000 to $99,999!!With health insurance coverage'),
#  ('B27015_019E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$75,000 to $99,999!!With health insurance coverage!!With private health insurance'),
#  ('B27015_020E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$75,000 to $99,999!!With health insurance coverage!!With public coverage'),
#  ('B27015_021E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$75,000 to $99,999!!No health insurance coverage'),
#  ('B27015_023E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$100,000 or more!!With health insurance coverage'),
#  ('B27015_024E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$100,000 or more!!With health insurance coverage!!With private health insurance'),
#  ('B27015_025E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$100,000 or more!!With health insurance coverage!!With public coverage'),
#  ('B27015_026E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2018 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total!!$100,000 or more!!No health insurance coverage'),
#  ('B27019_004E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!26 to 64 years!!Less than high school graduate!!With health insurance coverage'),
#  ('B27019_005E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!26 to 64 years!!Less than high school graduate!!With health insurance coverage!!With private health insurance'),
#  ('B27019_006E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!26 to 64 years!!Less than high school graduate!!With health insurance coverage!!With public coverage'),
#  ('B27019_007E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!26 to 64 years!!Less than high school graduate!!No health insurance coverage'),
#  ('B27019_009E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!26 to 64 years!!High school graduate (includes equivalency)!!With health insurance coverage'),
#  ('B27019_010E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!26 to 64 years!!High school graduate (includes equivalency)!!With health insurance coverage!!With private health insurance'),
#  ('B27019_011E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!26 to 64 years!!High school graduate (includes equivalency)!!With health insurance coverage!!With public coverage'),
#  ('B27019_012E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!26 to 64 years!!High school graduate (includes equivalency)!!No health insurance coverage'),
#  ('B27019_014E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!26 to 64 years!!Some college or associate's degree!!With health insurance coverage"),
#  ('B27019_015E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!26 to 64 years!!Some college or associate's degree!!With health insurance coverage!!With private health insurance"),
#  ('B27019_016E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!26 to 64 years!!Some college or associate's degree!!With health insurance coverage!!With public coverage"),
#  ('B27019_017E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!26 to 64 years!!Some college or associate's degree!!No health insurance coverage"),
#  ('B27019_019E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!26 to 64 years!!Bachelor's degree or higher!!With health insurance coverage"),
#  ('B27019_020E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!26 to 64 years!!Bachelor's degree or higher!!With health insurance coverage!!With private health insurance"),
#  ('B27019_021E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!26 to 64 years!!Bachelor's degree or higher!!With health insurance coverage!!With public coverage"),
#  ('B27019_022E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!26 to 64 years!!Bachelor's degree or higher!!No health insurance coverage"),
#  ('B27019_025E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!65 years and over!!Less than high school graduate!!With health insurance coverage'),
#  ('B27019_026E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!65 years and over!!Less than high school graduate!!With health insurance coverage!!With private health insurance'),
#  ('B27019_027E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!65 years and over!!Less than high school graduate!!With health insurance coverage!!With public coverage'),
#  ('B27019_028E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!65 years and over!!Less than high school graduate!!No health insurance coverage'),
#  ('B27019_030E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!65 years and over!!High school graduate (includes equivalency)!!With health insurance coverage'),
#  ('B27019_031E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!65 years and over!!High school graduate (includes equivalency)!!With health insurance coverage!!With private health insurance'),
#  ('B27019_032E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!65 years and over!!High school graduate (includes equivalency)!!With health insurance coverage!!With public coverage'),
#  ('B27019_033E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   'Estimate!!Total!!65 years and over!!High school graduate (includes equivalency)!!No health insurance coverage'),
#  ('B27019_035E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!65 years and over!!Some college or associate's degree!!With health insurance coverage"),
#  ('B27019_036E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!65 years and over!!Some college or associate's degree!!With health insurance coverage!!With private health insurance"),
#  ('B27019_037E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!65 years and over!!Some college or associate's degree!!With health insurance coverage!!With public coverage"),
#  ('B27019_038E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!65 years and over!!Some college or associate's degree!!No health insurance coverage"),
#  ('B27019_040E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!65 years and over!!Bachelor's degree or higher!!With health insurance coverage"),
#  ('B27019_041E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!65 years and over!!Bachelor's degree or higher!!With health insurance coverage!!With private health insurance"),
#  ('B27019_042E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!65 years and over!!Bachelor's degree or higher!!With health insurance coverage!!With public coverage"),
#  ('B27019_043E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY AGE BY EDUCATIONAL ATTAINMENT',
#   "Estimate!!Total!!65 years and over!!Bachelor's degree or higher!!No health insurance coverage"),
#  ('B27020_003E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Native Born!!With health insurance coverage'),
#  ('B27020_004E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Native Born!!With health insurance coverage!!With private health insurance'),
#  ('B27020_005E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Native Born!!With health insurance coverage!!With public coverage'),
#  ('B27020_006E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Native Born!!No health insurance coverage'),
#  ('B27020_009E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Foreign Born!!Naturalized!!With health insurance coverage'),
#  ('B27020_010E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Foreign Born!!Naturalized!!With health insurance coverage!!With private health insurance'),
#  ('B27020_011E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Foreign Born!!Naturalized!!With health insurance coverage!!With public coverage'),
#  ('B27020_012E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Foreign Born!!Naturalized!!No health insurance coverage'),
#  ('B27020_014E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Foreign Born!!Noncitizen!!With health insurance coverage'),
#  ('B27020_015E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Foreign Born!!Noncitizen!!With health insurance coverage!!With private health insurance'),
#  ('B27020_016E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Foreign Born!!Noncitizen!!With health insurance coverage!!With public coverage'),
#  ('B27020_017E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY CITIZENSHIP STATUS',
#   'Estimate!!Total!!Foreign Born!!Noncitizen!!No health insurance coverage'),
#  ('B27022_004E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Male!!Enrolled in school!!With health insurance coverage'),
#  ('B27022_005E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Male!!Enrolled in school!!No health insurance coverage'),
#  ('B27022_007E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Male!!Not enrolled in school!!With health insurance coverage'),
#  ('B27022_008E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Male!!Not enrolled in school!!No health insurance coverage'),
#  ('B27022_011E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Female!!Enrolled in school!!With health insurance coverage'),
#  ('B27022_012E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Female!!Enrolled in school!!No health insurance coverage'),
#  ('B27022_014E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Female!!Not enrolled in school!!With health insurance coverage'),
#  ('B27022_015E',
#   'HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Female!!Not enrolled in school!!No health insurance coverage'),
#  ('B27023_004E',
#   'PRIVATE HEALTH INSURANCE BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Male!!Enrolled in school!!With private health insurance coverage'),
#  ('B27023_005E',
#   'PRIVATE HEALTH INSURANCE BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Male!!Enrolled in school!!No private health insurance coverage'),
#  ('B27023_007E',
#   'PRIVATE HEALTH INSURANCE BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Male!!Not enrolled in school!!With private health insurance coverage'),
#  ('B27023_008E',
#   'PRIVATE HEALTH INSURANCE BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Male!!Not enrolled in school!!No private health insurance coverage'),
#  ('B27023_011E',
#   'PRIVATE HEALTH INSURANCE BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Female!!Enrolled in school!!With private health insurance coverage'),
#  ('B27023_012E',
#   'PRIVATE HEALTH INSURANCE BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Female!!Enrolled in school!!No private health insurance coverage'),
#  ('B27023_014E',
#   'PRIVATE HEALTH INSURANCE BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Female!!Not enrolled in school!!With private health insurance coverage'),
#  ('B27023_015E',
#   'PRIVATE HEALTH INSURANCE BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25',
#   'Estimate!!Total!!Female!!Not enrolled in school!!No private health insurance coverage'),
#  ('B992701_002E',
#   'ALLOCATION OF HEALTH INSURANCE COVERAGE',
#   'Estimate!!Total!!One or more health insurance items allocated'),
#  ('B992701_003E',
#   'ALLOCATION OF HEALTH INSURANCE COVERAGE',
#   'Estimate!!Total!!No health insurance items allocated'),
#  ('B992702_002E',
#   'ALLOCATION OF PRIVATE HEALTH INSURANCE',
#   'Estimate!!Total!!One or more private health insurance items allocated'),
#  ('B992702_003E',
#   'ALLOCATION OF PRIVATE HEALTH INSURANCE',
#   'Estimate!!Total!!No private health insurance items allocated'),
#  ('C27001A_003E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (WHITE ALONE)',
#   'Estimate!!Total!!Under 19 years!!With health insurance coverage'),
#  ('C27001A_004E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (WHITE ALONE)',
#   'Estimate!!Total!!Under 19 years!!No health insurance coverage'),
#  ('C27001A_006E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (WHITE ALONE)',
#   'Estimate!!Total!!19 to 64 years!!With health insurance coverage'),
#  ('C27001A_007E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (WHITE ALONE)',
#   'Estimate!!Total!!19 to 64 years!!No health insurance coverage'),
#  ('C27001A_009E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (WHITE ALONE)',
#   'Estimate!!Total!!65 years and over!!With health insurance coverage'),
#  ('C27001A_010E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (WHITE ALONE)',
#   'Estimate!!Total!!65 years and over!!No health insurance coverage'),
#  ('C27001B_003E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!Under 19 years!!With health insurance coverage'),
#  ('C27001B_004E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!Under 19 years!!No health insurance coverage'),
#  ('C27001B_006E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!19 to 64 years!!With health insurance coverage'),
#  ('C27001B_007E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!19 to 64 years!!No health insurance coverage'),
#  ('C27001B_009E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!65 years and over!!With health insurance coverage'),
#  ('C27001B_010E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!65 years and over!!No health insurance coverage'),
#  ('C27001C_003E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Total!!Under 19 years!!With health insurance coverage'),
#  ('C27001C_004E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Total!!Under 19 years!!No health insurance coverage'),
#  ('C27001C_006E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Total!!19 to 64 years!!With health insurance coverage'),
#  ('C27001C_007E',
#   'HEALTH INSURANCE COVERAGE STATUS BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Total!!19 to 64 years!!No health insurance coverage'),
#  ('C27001C_009E',
# ...
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY WORK EXPERIENCE',
#   'Estimate!!Total!!Did not work!!With health insurance coverage!!With Medicaid/means-tested public coverage'),
#  ('C27012_022E',
#   'HEALTH INSURANCE COVERAGE STATUS AND TYPE BY WORK EXPERIENCE',
#   'Estimate!!Total!!Did not work!!No health insurance coverage'),
#  ('C27013_003E',
#   'PRIVATE HEALTH INSURANCE BY WORK EXPERIENCE',
#   'Estimate!!Total!!Worked full-time, year-round!!With private health insurance'),
#  ('C27013_004E',
#   'PRIVATE HEALTH INSURANCE BY WORK EXPERIENCE',
#   'Estimate!!Total!!Worked full-time, year-round!!No private health insurance'),
#  ('C27013_006E',
#   'PRIVATE HEALTH INSURANCE BY WORK EXPERIENCE',
#   'Estimate!!Total!!Worked less than full-time, year-round!!With private health insurance'),
#  ('C27013_007E',
#   'PRIVATE HEALTH INSURANCE BY WORK EXPERIENCE',
#   'Estimate!!Total!!Worked less than full-time, year-round!!No private health insurance'),
#  ('C27013_009E',
#   'PRIVATE HEALTH INSURANCE BY WORK EXPERIENCE',
#   'Estimate!!Total!!Did not work!!With private health insurance'),
#  ('C27013_010E',
#   'PRIVATE HEALTH INSURANCE BY WORK EXPERIENCE',
#   'Estimate!!Total!!Did not work!!No private health insurance'),
#  ('C27016_004E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!Under 19 years!!With health insurance coverage'),
#  ('C27016_005E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!Under 19 years!!No health insurance coverage'),
#  ('C27016_007E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!19 to 64 years!!With health insurance coverage'),
#  ('C27016_008E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!19 to 64 years!!No health insurance coverage'),
#  ('C27016_010E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!65 years and over!!With health insurance coverage'),
#  ('C27016_011E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!65 years and over!!No health insurance coverage'),
#  ('C27016_014E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!Under 19 years!!With health insurance coverage'),
#  ('C27016_015E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!Under 19 years!!No health insurance coverage'),
#  ('C27016_017E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!19 to 64 years!!With health insurance coverage'),
#  ('C27016_018E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!19 to 64 years!!No health insurance coverage'),
#  ('C27016_020E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!65 years and over!!With health insurance coverage'),
#  ('C27016_021E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!65 years and over!!No health insurance coverage'),
#  ('C27016_024E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!Under 19 years!!With health insurance coverage'),
#  ('C27016_025E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!Under 19 years!!No health insurance coverage'),
#  ('C27016_027E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!19 to 64 years!!With health insurance coverage'),
#  ('C27016_028E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!19 to 64 years!!No health insurance coverage'),
#  ('C27016_030E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!65 years and over!!With health insurance coverage'),
#  ('C27016_031E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!65 years and over!!No health insurance coverage'),
#  ('C27016_034E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!Under 19 years!!With health insurance coverage'),
#  ('C27016_035E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!Under 19 years!!No health insurance coverage'),
#  ('C27016_037E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!19 to 64 years!!With health insurance coverage'),
#  ('C27016_038E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!19 to 64 years!!No health insurance coverage'),
#  ('C27016_040E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!65 years and over!!With health insurance coverage'),
#  ('C27016_041E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!65 years and over!!No health insurance coverage'),
#  ('C27016_044E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!Under 19 years!!With health insurance coverage'),
#  ('C27016_045E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!Under 19 years!!No health insurance coverage'),
#  ('C27016_047E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!19 to 64 years!!With health insurance coverage'),
#  ('C27016_048E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!19 to 64 years!!No health insurance coverage'),
#  ('C27016_050E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!65 years and over!!With health insurance coverage'),
#  ('C27016_051E',
#   'HEALTH INSURANCE COVERAGE STATUS BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!65 years and over!!No health insurance coverage'),
#  ('C27017_004E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!Under 19 years!!With private health insurance'),
#  ('C27017_005E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!Under 19 years!!No private health insurance'),
#  ('C27017_007E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!19 to 64 years!!With private health insurance'),
#  ('C27017_008E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!19 to 64 years!!No private health insurance'),
#  ('C27017_010E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!65 years and over!!With private health insurance'),
#  ('C27017_011E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!Under 1.00 of poverty threshold!!65 years and over!!No private health insurance'),
#  ('C27017_014E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!Under 19 years!!With private health insurance'),
#  ('C27017_015E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!Under 19 years!!No private health insurance'),
#  ('C27017_017E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!19 to 64 years!!With private health insurance'),
#  ('C27017_018E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!19 to 64 years!!No private health insurance'),
#  ('C27017_020E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!65 years and over!!With private health insurance'),
#  ('C27017_021E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.00 to 1.37 of poverty threshold!!65 years and over!!No private health insurance'),
#  ('C27017_024E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!Under 19 years!!With private health insurance'),
#  ('C27017_025E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!Under 19 years!!No private health insurance'),
#  ('C27017_027E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!19 to 64 years!!With private health insurance'),
#  ('C27017_028E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!19 to 64 years!!No private health insurance'),
#  ('C27017_030E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!65 years and over!!With private health insurance'),
#  ('C27017_031E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!1.38 to 1.99 of poverty threshold!!65 years and over!!No private health insurance'),
#  ('C27017_034E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!Under 19 years!!With private health insurance'),
#  ('C27017_035E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!Under 19 years!!No private health insurance'),
#  ('C27017_037E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!19 to 64 years!!With private health insurance'),
#  ('C27017_038E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!19 to 64 years!!No private health insurance'),
#  ('C27017_040E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!65 years and over!!With private health insurance'),
#  ('C27017_041E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!2.00 to 3.99 of poverty threshold!!65 years and over!!No private health insurance'),
#  ('C27017_044E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!Under 19 years!!With private health insurance'),
#  ('C27017_045E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!Under 19 years!!No private health insurance'),
#  ('C27017_047E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!19 to 64 years!!With private health insurance'),
#  ('C27017_048E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!19 to 64 years!!No private health insurance'),
#  ('C27017_050E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!65 years and over!!With private health insurance'),
#  ('C27017_051E',
#   'PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY AGE',
#   'Estimate!!Total!!4.00 of poverty threshold and over!!65 years and over!!No private health insurance'),
#  ('C27021_004E',
#   'HEALTH INSURANCE COVERAGE STATUS  BY LIVING ARRANGEMENT',
#   'Estimate!!Total!!In family households!!In married couple families!!With health insurance coverage'),
#  ('C27021_005E',
#   'HEALTH INSURANCE COVERAGE STATUS  BY LIVING ARRANGEMENT',
#   'Estimate!!Total!!In family households!!In married couple families!!No health insurance coverage'),
#  ('C27021_008E',
#   'HEALTH INSURANCE COVERAGE STATUS  BY LIVING ARRANGEMENT',
#   'Estimate!!Total!!In family households!!In other families!!Male householder, no wife present!!With health insurance coverage'),
#  ('C27021_009E',
#   'HEALTH INSURANCE COVERAGE STATUS  BY LIVING ARRANGEMENT',
#   'Estimate!!Total!!In family households!!In other families!!Male householder, no wife present!!No health insurance coverage'),
#  ('C27021_011E',
#   'HEALTH INSURANCE COVERAGE STATUS  BY LIVING ARRANGEMENT',
#   'Estimate!!Total!!In family households!!In other families!!Female householder, no husband present!!With health insurance coverage'),
#  ('C27021_012E',
#   'HEALTH INSURANCE COVERAGE STATUS  BY LIVING ARRANGEMENT',
#   'Estimate!!Total!!In family households!!In other families!!Female householder, no husband present!!No health insurance coverage'),
#  ('C27021_014E',
#   'HEALTH INSURANCE COVERAGE STATUS  BY LIVING ARRANGEMENT',
#   'Estimate!!Total!!In non-family households and other living arrangements!!With health insurance coverage'),
#  ('C27021_015E',
#   'HEALTH INSURANCE COVERAGE STATUS  BY LIVING ARRANGEMENT',
#   'Estimate!!Total!!In non-family households and other living arrangements!!No health insurance coverage')]

# %%
censusdata.printtable(censusdata.censustable('acs5', 2018, 'B27010'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B27010_001E  | TYPES OF HEALTH INSURANCE COVE | !! Estimate Total                                        | int
# B27010_002E  | TYPES OF HEALTH INSURANCE COVE | !! !! Estimate Total Under 19 years                      | int
# B27010_003E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total Under 19 years With one type of  | int
# B27010_004E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With one type  | int
# B27010_005E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With one type  | int
# B27010_006E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With one type  | int
# B27010_007E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With one type  | int
# B27010_008E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With one type  | int
# B27010_009E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With one type  | int
# B27010_010E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total Under 19 years With two or more  | int
# B27010_011E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With two or mo | int
# B27010_012E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With two or mo | int
# B27010_013E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With two or mo | int
# B27010_014E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With two or mo | int
# B27010_015E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With two or mo | int
# B27010_016E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total Under 19 years With two or mo | int
# B27010_017E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total Under 19 years No health insuran | int
# B27010_018E  | TYPES OF HEALTH INSURANCE COVE | !! !! Estimate Total 19 to 34 years                      | int
# B27010_019E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 19 to 34 years With one type of  | int
# B27010_020E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With one type  | int
# B27010_021E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With one type  | int
# B27010_022E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With one type  | int
# B27010_023E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With one type  | int
# B27010_024E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With one type  | int
# B27010_025E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With one type  | int
# B27010_026E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 19 to 34 years With two or more  | int
# B27010_027E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With two or mo | int
# B27010_028E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With two or mo | int
# B27010_029E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With two or mo | int
# B27010_030E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With two or mo | int
# B27010_031E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With two or mo | int
# B27010_032E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 19 to 34 years With two or mo | int
# B27010_033E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 19 to 34 years No health insuran | int
# B27010_034E  | TYPES OF HEALTH INSURANCE COVE | !! !! Estimate Total 35 to 64 years                      | int
# B27010_035E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 35 to 64 years With one type of  | int
# B27010_036E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With one type  | int
# B27010_037E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With one type  | int
# B27010_038E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With one type  | int
# B27010_039E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With one type  | int
# B27010_040E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With one type  | int
# B27010_041E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With one type  | int
# B27010_042E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 35 to 64 years With two or more  | int
# B27010_043E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With two or mo | int
# B27010_044E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With two or mo | int
# B27010_045E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With two or mo | int
# B27010_046E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With two or mo | int
# B27010_047E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With two or mo | int
# B27010_048E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With two or mo | int
# B27010_049E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 35 to 64 years With two or mo | int
# B27010_050E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 35 to 64 years No health insuran | int
# B27010_051E  | TYPES OF HEALTH INSURANCE COVE | !! !! Estimate Total 65 years and over                   | int
# B27010_052E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 65 years and over With one type  | int
# B27010_053E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With one ty | int
# B27010_054E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With one ty | int
# B27010_055E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With one ty | int
# B27010_056E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With one ty | int
# B27010_057E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With one ty | int
# B27010_058E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 65 years and over With two or mo | int
# B27010_059E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With two or | int
# B27010_060E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With two or | int
# B27010_061E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With two or | int
# B27010_062E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With two or | int
# B27010_063E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With two or | int
# B27010_064E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With two or | int
# B27010_065E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! !! Estimate Total 65 years and over With two or | int
# B27010_066E  | TYPES OF HEALTH INSURANCE COVE | !! !! !! Estimate Total 65 years and over No health insu | int
# -------------------------------------------------------------------------------------------------------------------

# %%
censusdata.printtable(censusdata.censustable('acs5', 2018, 'B28004'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B28004_001E  | HOUSEHOLD INCOME IN THE LAST 1 | !! Estimate Total                                        | int
# B28004_002E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! Estimate Total Less than $10,000                   | int
# B28004_003E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total Less than $10,000 With dial-up I | int
# B28004_004E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total Less than $10,000 With a broadba | int
# B28004_005E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total Less than $10,000 Without an Int | int
# B28004_006E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! Estimate Total $10,000 to $19,999                  | int
# B28004_007E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $10,000 to $19,999 With dial-up  | int
# B28004_008E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $10,000 to $19,999 With a broadb | int
# B28004_009E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $10,000 to $19,999 Without an In | int
# B28004_010E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! Estimate Total $20,000 to $34,999                  | int
# B28004_011E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $20,000 to $34,999 With dial-up  | int
# B28004_012E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $20,000 to $34,999 With a broadb | int
# B28004_013E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $20,000 to $34,999 Without an In | int
# B28004_014E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! Estimate Total $35,000 to $49,999                  | int
# B28004_015E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $35,000 to $49,999 With dial-up  | int
# B28004_016E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $35,000 to $49,999 With a broadb | int
# B28004_017E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $35,000 to $49,999 Without an In | int
# B28004_018E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! Estimate Total $50,000 to $74,999                  | int
# B28004_019E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $50,000 to $74,999 With dial-up  | int
# B28004_020E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $50,000 to $74,999 With a broadb | int
# B28004_021E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $50,000 to $74,999 Without an In | int
# B28004_022E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! Estimate Total $75,000 or more                     | int
# B28004_023E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $75,000 or more With dial-up Int | int
# B28004_024E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $75,000 or more With a broadband | int
# B28004_025E  | HOUSEHOLD INCOME IN THE LAST 1 | !! !! !! Estimate Total $75,000 or more Without an Inter | int
# -------------------------------------------------------------------------------------------------------------------

# %%
income_data = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', '091'),
                                 ('block group', '*')]),['B28004_002E','B28004_006E','B28004_010E','B28004_014E',
                                                         'B28004_018E','B28004_022E'])

# %%
for i in county_list[1:]:
    income_data_new = censusdata.download('acs5', 2018,
           censusdata.censusgeo([('state', '12'),
                                 ('county', i), ('block group', '*')]),['B28004_002E','B28004_006E','B28004_010E','B28004_014E',
                                                         'B28004_018E','B28004_022E'])
    income_data = income_data.append(income_data_new)

# %%
income_data['Income: Less than 10,000'] = income_data.B28004_002E
income_data['Income: Between 10,000 to 19,999'] = income_data.B28004_006E
income_data['Income: Between 20,000 to 34,999'] = income_data.B28004_010E
income_data['Income: Between 35,000 to 49,999'] = income_data.B28004_014E
income_data['Income: Between 50,000 to 74,999'] = income_data.B28004_018E
income_data['Income: More than 75,000'] = income_data.B28004_022E
income_data = income_data[['Income: Less than 10,000','Income: Between 10,000 to 19,999',
                          'Income: Between 20,000 to 34,999','Income: Between 35,000 to 49,999',
                          'Income: Between 50,000 to 74,999','Income: More than 75,000']]
income_data
# Out:
#                                                     Income: Less than 10,000  Income: Between 10,000 to 19,999  Income: Between 20,000 to 34,999  Income: Between 35,000 to 49,999  Income: Between 50,000 to 74,999  Income: More than 75,000
# Block Group 2, Census Tract 221, Okaloosa Count...                         0                                84                                92                                60                                79                       154
# Block Group 1, Census Tract 221, Okaloosa Count...                       155                               151                               106                               132                               173                       156
# Block Group 2, Census Tract 204, Okaloosa Count...                        67                               131                               279                                25                               149                       154
# Block Group 1, Census Tract 204, Okaloosa Count...                        46                                18                                77                               144                                77                       110
# Block Group 2, Census Tract 205, Okaloosa Count...                        82                                32                                57                                54                                36                        80
# ...                                                                      ...                               ...                               ...                               ...                               ...                       ...
# Block Group 3, Census Tract 9705, Monroe County...                        24                                 0                                28                                25                                86                       135
# Block Group 2, Census Tract 9707, Monroe County...                        10                                 7                                32                                 7                                 7                        56
# Block Group 1, Census Tract 9708, Monroe County...                        25                                 0                                56                                53                                41                       300
# Block Group 3, Census Tract 9713, Monroe County...                        29                                56                                94                                79                                26                        41
# Block Group 1, Census Tract 9710.02, Monroe Cou...                         7                                 0                                12                                41                                22                        87
#
# [11442 rows x 6 columns]

# %%
result = pd.concat([age_data,race_data,education_data,income_data,employment_data,health_ins_data],axis=1,sort=False)

# %%
result
# Out:
#                                                     Age: 20-30  Age: 30-45  Age: 45-60  Age: 60+  Race: White  Race: Black/African American  Race: American Indian and Alaska Native  Race: Asian  Race: Hawaiian and Pacific Islander  Education: Below Middle School  ...  Income: Between 20,000 to 34,999  Income: Between 35,000 to 49,999  Income: Between 50,000 to 74,999  Income: More than 75,000  Employment: Employed  Employment: Unemployed  Employment: Not In Labor Force  Insurance: 2 or More  Insurance: One  Insurance: No
# Block Group 2, Census Tract 221, Okaloosa Count...         160         327         278       315          946                           200                                        0           36                                    0                              43  ...                                92                                60                                79                       154                   507                      26                             528                   414             687            197
# Block Group 1, Census Tract 221, Okaloosa Count...         368         476         308       501         1407                           265                                        7           31                                  141                              44  ...                               106                               132                               173                       156                   799                      96                             683                   442            1101            487
# Block Group 2, Census Tract 204, Okaloosa Count...         916         868         301       436         2662                           343                                       13            0                                    0                             141  ...                               279                                25                               149                       154                   778                     275                            1392                   438            1932            236
# Block Group 1, Census Tract 204, Okaloosa Count...         292         210         352       282         1074                           116                                        0           19                                    0                              18  ...                                77                               144                                77                       110                   549                       0                             540                   369             480            456
# Block Group 2, Census Tract 205, Okaloosa Count...         188          78          91       174          380                           127                                        0           15                                   30                               0  ...                                57                                54                                36                        80                   304                      35                             192                   232             317             67
# ...                                                        ...         ...         ...       ...          ...                           ...                                      ...          ...                                  ...                             ...  ...                               ...                               ...                               ...                       ...                   ...                     ...                             ...                   ...             ...            ...
# Block Group 3, Census Tract 9705, Monroe County...         103         114         169       268          765                             0                                        0            0                                    0                              10  ...                                28                                25                                86                       135                   402                       0                             252                   163             447            178
# Block Group 2, Census Tract 9707, Monroe County...         139          34          91        59          344                             0                                        0            0                                    0                               0  ...                                32                                 7                                 7                        56                   197                      10                             116                    34             286             31
# Block Group 1, Census Tract 9708, Monroe County...          48         187         292       408          989                             0                                        0            0                                    0                              21  ...                                56                                53                                41                       300                   503                       0                             432                   216             764             57
# Block Group 3, Census Tract 9713, Monroe County...         268         150         168       225          761                            37                                        0           22                                    0                              48  ...                                94                                79                                26                        41                   282                      15                             284                   143             180            289
# Block Group 1, Census Tract 9710.02, Monroe Cou...          51          34         167       131          421                            30                                        0            0                                    0                               4  ...                                12                                41                                22                        87                   269                       0                             106                   114             282             47
#
# [11442 rows x 25 columns]

# %%
result.to_csv("result.csv",index_label = "Block Group")
